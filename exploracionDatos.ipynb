# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# Configuración visual
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %%
ruta = "Datos_Etapa-2.csv"
df = pd.read_csv(ruta)

# %%
df.head()
# Out:
#      pH  Dureza   Sólidos  Cloraminas  Sulfatos  Conductividad  \
# 0   NaN  204.89  20791.32        7.30    368.52         564.31
# 1  3.72  129.42  18630.06        6.64       NaN         592.89
# 2  8.10  224.24  19909.54        9.28       NaN         418.61
# 3  8.32  214.37  22018.42        8.06    356.89         363.27
# 4  9.09  181.10  17978.99        6.55    310.14         398.41
#
#    Carbono_orgánico  Trihalometanos  Turbidez Potabilidad
# 0             10.38           86.99      2.96          NO
# 1             15.18           56.33      4.50          NO
# 2             16.87           66.42      3.06          NO
# 3             18.44          100.34      4.63          NO
# 4             11.56           32.00      4.08          NO

# %%
df.shape
# Out:
# (3276, 10)

# %%
df.columns
# Out:
# Index(['pH', 'Dureza', 'Sólidos', 'Cloraminas', 'Sulfatos', 'Conductividad',
#        'Carbono_orgánico', 'Trihalometanos', 'Turbidez', 'Potabilidad'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pH                2785 non-null   float64
#  1   Dureza            3276 non-null   float64
#  2   Sólidos           3276 non-null   float64
#  3   Cloraminas        3276 non-null   float64
#  4   Sulfatos          2495 non-null   float64
#  5   Conductividad     3276 non-null   float64
#  6   Carbono_orgánico  3276 non-null   float64
#  7   Trihalometanos    3114 non-null   float64
#  8   Turbidez          3276 non-null   float64
#  9   Potabilidad       3276 non-null   str
# dtypes: float64(9), str(1)
# memory usage: 256.1 KB

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pH                2785 non-null   float64
#  1   Dureza            3276 non-null   float64
#  2   Sólidos           3276 non-null   float64
#  3   Cloraminas        3276 non-null   float64
#  4   Sulfatos          2495 non-null   float64
#  5   Conductividad     3276 non-null   float64
#  6   Carbono_orgánico  3276 non-null   float64
#  7   Trihalometanos    3114 non-null   float64
#  8   Turbidez          3276 non-null   float64
#  9   Potabilidad       3276 non-null   str
# dtypes: float64(9), str(1)
# memory usage: 256.1 KB

# %%
df.describe(include="object")
# Out:
# /tmp/ipykernel_42578/702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#        Potabilidad
# count         3276
# unique           2
# top             NO
# freq          1998

# %%
df.isnull().sum()
# Out:
# pH                  491
# Dureza                0
# Sólidos               0
# Cloraminas            0
# Sulfatos            781
# Conductividad         0
# Carbono_orgánico      0
# Trihalometanos      162
# Turbidez              0
# Potabilidad           0
# dtype: int64

# %%
(df.isnull().mean() * 100).sort_values(ascending=False)
# Out:
# Sulfatos            23.840049
# pH                  14.987790
# Trihalometanos       4.945055
# Dureza               0.000000
# Cloraminas           0.000000
# Sólidos              0.000000
# Conductividad        0.000000
# Carbono_orgánico     0.000000
# Turbidez             0.000000
# Potabilidad          0.000000
# dtype: float64

# %%
sns.heatmap(df.isnull(), cbar=False)
plt.title("Mapa de valores nulos")
plt.show()

# %%
df.hist(bins=30)
plt.tight_layout()
plt.show()

# %%
sns.countplot(x="Potabilidad", data=df)
plt.title("Distribución de la variable objetivo (Potabilidad)")
plt.xlabel("Potabilidad (NO / SI)")
plt.ylabel("Cantidad de muestras")
plt.show()

# %%
df.isnull().sum()
# Out:
# pH                  491
# Dureza                0
# Sólidos               0
# Cloraminas            0
# Sulfatos            781
# Conductividad         0
# Carbono_orgánico      0
# Trihalometanos      162
# Turbidez              0
# Potabilidad           0
# dtype: int64

# %%
(df.isnull().mean() * 100).sort_values(ascending=False)
# Out:
# Sulfatos            23.840049
# pH                  14.987790
# Trihalometanos       4.945055
# Dureza               0.000000
# Cloraminas           0.000000
# Sólidos              0.000000
# Conductividad        0.000000
# Carbono_orgánico     0.000000
# Turbidez             0.000000
# Potabilidad          0.000000
# dtype: float64

# %%
sns.heatmap(df.isnull(), cbar=False)
plt.title("Mapa de valores nulos")
plt.show()

# %%
df.describe()
# Out:
#                 pH       Dureza       Sólidos   Cloraminas     Sulfatos  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080804   196.369481  22014.092415     7.122241   333.775784
# std       1.594369    32.879680   8768.570852     1.583143    41.416864
# min       0.000000    47.430000    320.940000     0.350000   129.000000
# 25%       6.090000   176.847500  15666.687500     6.130000   307.695000
# 50%       7.040000   196.965000  20927.830000     7.130000   333.070000
# 75%       8.060000   216.670000  27332.760000     8.112500   359.950000
# max      14.000000   323.120000  61227.200000    13.130000   481.030000
#
#        Conductividad  Carbono_orgánico  Trihalometanos     Turbidez
# count    3276.000000       3276.000000     3114.000000  3276.000000
# mean      426.205171         14.284921       66.396281     3.966731
# std        80.824123          3.308232       16.174983     0.780354
# ...

# %%
df.drop(columns="Potabilidad").hist(bins=30)
plt.suptitle("Distribución de variables numéricas", y=1.02)
plt.tight_layout()
plt.show()

# %%
for col in df.drop(columns="Potabilidad").columns:
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot de {col}")
    plt.show()
